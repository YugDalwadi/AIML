# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %%
import torch.functional as F
from torch import nn

#input img -> h_dim -> std,mean
class VAE(nn.Module):
    def __init__(self,input_dims, hidden_dim=200, latent_dim=20):
        super().__init__()
        self.input_dims = input_dims
        self.hidden_dim = hidden_dim
        self.latent_dim = latent_dim

        self.img_to_hidden = nn.Linear(input_dims, hidden_dim)
        self.hidden_to_sigma = nn.Linear(hidden_dim,)
        self.hidden_to_mu = nn.Linear(hidden_dim)
        
    def encoder(self,x): # takes p to give q_phi(z|x)
        pass
    
    def decoder(self,z): # takes q to give p_theta(x|z)
        pass
    def forward(self,x):
        pass
